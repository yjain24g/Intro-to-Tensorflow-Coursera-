# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train = x_train/255.0
y_train = y_train/255.0

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('acc') >= 0.99):
            print("Reached 99% accuracy so cancelling trining!")
            self.model.stop_training = True

callbacks = myCallback()

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(512, activation = tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation = tf.nn.softmax)
                                   ])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0020 - accuracy: 0.0987
# Epoch 2/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 6.7420e-07 - accuracy: 0.0987
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.5208e-07 - accuracy: 0.0987
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 4.6445e-08 - accuracy: 0.0987
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.6137e-08 - accuracy: 0.0987
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 6.0896e-09 - accuracy: 0.0987
# Epoch 7/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 2.5908e-09 - accuracy: 0.0987
# Epoch 8/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.2398e-09 - accuracy: 0.0987
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 6.6161e-10 - accuracy: 0.0987
# Epoch 10/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 3.7154e-10 - accuracy: 0.0987
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6946cf8a391a> in <module>
#      23               metrics=['accuracy'])
#      24
# ---> 25 model.fit(x_train, y_train, epochs = 10)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:
